# %%
from PIL import Image
import os

# %%
print(len(os.listdir("/lfs/Nevils/Unet/inputs/art_noise_NestedUNet_woDS/0")))
Image.open("/lfs/Nevils/Unet/inputs/art_noise_NestedUNet_woDS/0/Tile_r010_c000.png")
# Out:
# 200
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7F03BC21C910>

# %%
for all res in os.listdir("/lfs/Nevils/Unet/inputs/art_noise_NestedUNet_woDS/0"):
    img=Image.open("/lfs/Nevils/Unet/inputs/art_noise_NestedUNet_woDS/0/"+res)
    img.save("Results/"+res)
